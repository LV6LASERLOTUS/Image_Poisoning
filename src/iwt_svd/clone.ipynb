# %%
# %cd repos
# !git --version
# Out:
# D:\sina_intern\jupyterProject\467\repos
# git version 2.49.0.windows.1

# %%
# !git clone https://github.com/christofer-f/IntegerWaveletTransform.git
# Out:
# Cloning into 'IntegerWaveletTransform'...

# %%
# !dir
# Out:
#  驱动器 D 中的卷没有标签。
#  卷的序列号是 5629-7A2C
#
#  D:\sina_intern\jupyterProject\467\repos 的目录
#
# 2025/11/30  18:01    <DIR>          .
# 2025/11/30  18:01    <DIR>          ..
# 2025/11/30  18:01    <DIR>          IntegerWaveletTransform
#                0 个文件              0 字节
#                3 个目录 575,023,063,040 可用字节

# %%
# %cd ..
# Out:
# D:\sina_intern\jupyterProject\467
