# %%
import torch
from torch import Tensor

# %%
from models import DoubleConv,VGG13
# Out:
# ============ Initializing ============

# %%
if __name__ == '__main__':
    
    double_conv = DoubleConv(224,244)
    print(double_conv)
    
    img = torch.randn(1, 3, 224, 224)
    model = VGG13(in_channels=3,num_channels=3)
    output = model(img)
    
    print(f'\n\nModel Output: {features.shape}')
# Out:
# DoubleConv(
#   (conv_op): Sequential(
#     (0): Conv2d(224, 244, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(244, 244, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# )
#
#
# Model Output: torch.Size([1, 25088])

# %%
features:Tensor=model.extract_features(img)
print(f'Features size: {features.shape}')
# Out:
# Features size: torch.Size([1, 25088])
